# %% [markdown]
# ### Main Declaration Layer:

# %% [markdown]
# ### Utility Function Layer:

# %%
# Modules will be here:
import torch, os, sys, subprocess, importlib
from google.colab import drive

# Utility Function Layer:
def testDependency(): # Test Dependencies for Entire Process:
    packages = {
        "colorama": "colorama",
        "IPython" : "IPython",
    }
    missings = list(
        name for module, name in packages.items() if importlib.util.find_spec(module) is None
    )
    if missings:
        subprocess.check_call(
            [sys.executable, "-m", "pip", "install", *missings]
        )
        importlib.invalidate_caches()
    return

def checkResources(): # Check the resource type allocated to the Colab runtime:
    match torch.cuda.is_available():
        case True:
            print(f"{torch.cuda.device_count()} GPU(s) are available.\n")
        case False:
            print(f"No GPU: Using default resources -> {torch.__version__}\n")
    return

def loadScriptFile(): # Load & Execute the target file from GitHub:
    URL = "https://raw.githubusercontent.com/Landau184927/practice/main/test.py"
    # !wget -q -O test.py "$URL"
    # %run test.py 1
    return

def initializeTask(): # Initialize the Colab preparation process:
    PATH = "/content/drive"
    checkResources()
    testDependency()
    match os.path.exists(PATH):
        case True:
            return
        case False:
            drive.mount(PATH)
    return

def _initializer_():
    initializeTask()
    loadScriptFile()
    return

# Task Execution Layer:
_initializer_()
# Out:
# No GPU: Using default resources -> 2.11.0+cpu
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_129170/3577256942.py in <cell line: 0>()
#      51
#      52 # Task Execution Layer:
# ---> 53 _initializer_()
#
# /tmp/ipykernel_129170/3577256942.py in _initializer_()
#      47 def _initializer_():
#      48     initializeTask()
# ---> 49     loadScriptFile()
#      50     return
#      51
#
# /tmp/ipykernel_129170/3577256942.py in loadScriptFile()
#      30     URL = "https://raw.githubusercontent.com/Landau184927/practice/main/test.py"
#      31     get_ipython().system('wget -q -O test.py "$URL"')
# ---> 32     subprocess.run([sys.executable, "test.py", "1"], check = True)
#      33     #%run test.py 1
#      34     return
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569         retcode = process.poll()
#     570         if check and retcode:
# --> 571             raise CalledProcessError(retcode, process.args,
#     572                                      output=stdout, stderr=stderr)
#     573     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['/usr/bin/python3', 'test.py', '1']' returned non-zero exit status 1.

# %% [markdown]
# ### Task Execution Layer:

# %%
# Out:
# <pandas.io.formats.style.Styler object at 0x7a4747422990>
