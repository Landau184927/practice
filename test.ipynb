# %% [markdown]
# ### 주의사항:
# * main.ipynb에서는 로컬에서 작성된 *.py 파일들을 종합하여 colab에서 실행.

# %% [markdown]
# ### Connection set-up:

# %%
import torch

# %%
def checkResource():
    match torch.cuda.is_available():
        case True:
            print(f"{torch.cuda.device_count()} GPU(s) are available.")
        case False:
            print(f"No GPU. Using default resources: {torch.__version__}")
    return

def loadAIScripts():
    URL = "https://raw.githubusercontent.com/" "Landau184927/repository/practice.py"
    # !wget -q -O test.py "$URL"
    # !python test.py
    return

# %%
import torch, os
from google.colab import drive

PATH = "/content/drive"

match os.path.exists(PATH):
    case False:
        print("Drive is already mounted.")
    case True:
        drive.mount(PATH)
        checkResource()
        loadAIScripts()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# No GPU. Using default resources: 2.11.0+cpu
