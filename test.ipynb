# %% [markdown]
# ### Main Declaration Layer:

# %% [markdown]
# ### Utility Function Layer:

# %%
# Modules will be here:
import torch, os, sys, subprocess, importlib
from google.colab import drive

# Utility Function Layer:
def testDependency(): # Test Dependencies for Entire Process:
    packages = {
        "colorama": "colorama",
        "IPython" : "IPython",
    }
    missings = list(
        name for module, name in packages.items() if importlib.util.find_spec(module) is None
    )
    if missings:
        subprocess.check_call(
            [sys.executable, "-m", "pip", "install", *missings]
        )
        importlib.invalidate_caches()
    return

def checkResources(): # Check the resource type allocated to the Colab runtime:
    match torch.cuda.is_available():
        case True:
            print(f"{torch.cuda.device_count()} GPU(s) are available.\n")
        case False:
            print(f"No GPU: Using default resources -> {torch.__version__}\n")
    return

def loadScriptFile(): # Load & Execute the target file from GitHub:
    URL = "https://raw.githubusercontent.com/Landau184927/practice/main/test.py"
    # !wget -q -O test.py "$URL"
    # %run test.py 1
    return

def initializeTask(): # Initialize the Colab preparation process:
    PATH = "/content/drive"
    checkResources()
    testDependency()
    match os.path.exists(PATH):
        case True:
            return
        case False:
            drive.mount(PATH)
    return

def _initializer_():
    initializeTask()
    loadScriptFile()
    return

# Task Execution Layer:
_initializer_()
# Out:
# No GPU: Using default resources -> 2.11.0+cpu
#
# The following shows a sample (10 rows) of BMI data for 500 people.
# <style type="text/css">
# </style>
# <table id="T_90151" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_90151_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_90151_level0_col1" class="col_heading level0 col1" >Height</th>
#       <th id="T_90151_level0_col2" class="col_heading level0 col2" >Weight</th>
#       <th id="T_90151_level0_col3" class="col_heading level0 col3" >Label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_90151_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_90151_row0_col1" class="data row0 col1" >174</td>
#       <td id="T_90151_row0_col2" class="data row0 col2" >96</td>
#       <td id="T_90151_row0_col3" class="data row0 col3" >4</td>
#     </tr>
#     <tr>
#       <td id="T_90151_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_90151_row1_col1" class="data row1 col1" >189</td>
#       <td id="T_90151_row1_col2" class="data row1 col2" >87</td>
#       <td id="T_90151_row1_col3" class="data row1 col3" >2</td>
#     </tr>
#     <tr>
#       <td id="T_90151_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_90151_row2_col1" class="data row2 col1" >185</td>
#       <td id="T_90151_row2_col2" class="data row2 col2" >110</td>
#       <td id="T_90151_row2_col3" class="data row2 col3" >4</td>
#     </tr>
#     <tr>
#       <td id="T_90151_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_90151_row3_col1" class="data row3 col1" >195</td>
#       <td id="T_90151_row3_col2" class="data row3 col2" >104</td>
#       <td id="T_90151_row3_col3" class="data row3 col3" >3</td>
#     </tr>
#     <tr>
#       <td id="T_90151_row4_col0" class="data row4 col0" >Male</td>
#       <td id="T_90151_row4_col1" class="data row4 col1" >149</td>
#       <td id="T_90151_row4_col2" class="data row4 col2" >61</td>
#       <td id="T_90151_row4_col3" class="data row4 col3" >3</td>
#     </tr>
#     <tr>
#       <td id="T_90151_row5_col0" class="data row5 col0" >Male</td>
#       <td id="T_90151_row5_col1" class="data row5 col1" >189</td>
#       <td id="T_90151_row5_col2" class="data row5 col2" >104</td>
#       <td id="T_90151_row5_col3" class="data row5 col3" >3</td>
#     </tr>
#     <tr>
#       <td id="T_90151_row6_col0" class="data row6 col0" >Male</td>
#       <td id="T_90151_row6_col1" class="data row6 col1" >147</td>
#       <td id="T_90151_row6_col2" class="data row6 col2" >92</td>
#       <td id="T_90151_row6_col3" class="data row6 col3" >5</td>
#     </tr>
#     <tr>
#       <td id="T_90151_row7_col0" class="data row7 col0" >Male</td>
#       <td id="T_90151_row7_col1" class="data row7 col1" >154</td>
#       <td id="T_90151_row7_col2" class="data row7 col2" >111</td>
#       <td id="T_90151_row7_col3" class="data row7 col3" >5</td>
#     </tr>
#     <tr>
#       <td id="T_90151_row8_col0" class="data row8 col0" >Male</td>
#       <td id="T_90151_row8_col1" class="data row8 col1" >174</td>
#       <td id="T_90151_row8_col2" class="data row8 col2" >90</td>
#       <td id="T_90151_row8_col3" class="data row8 col3" >3</td>
#     </tr>
#     <tr>
#       <td id="T_90151_row9_col0" class="data row9 col0" >Female</td>
#       <td id="T_90151_row9_col1" class="data row9 col1" >169</td>
#       <td id="T_90151_row9_col2" class="data row9 col2" >103</td>
#       <td id="T_90151_row9_col3" class="data row9 col3" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Task Execution Layer:

# %%
# Out:
# <pandas.io.formats.style.Styler object at 0x7a4747422990>
