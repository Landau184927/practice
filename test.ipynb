# %% [markdown]
# ### Main Declaration Layer:

# %% [markdown]
# ### Utility Function Layer:

# %%
# Modules will be here:
import torch, os, sys, subprocess, importlib
from google.colab import drive

# Utility Function Layer:
def testDependency(): # Test Dependencies for Entire Process:
    packages = {
        "colorama": "colorama",
        "IPython" : "IPython",
    }
    missings = list(
        name for module, name in packages.items() if importlib.util.find_spec(module) is None
    )
    if missings:
        subprocess.check_call(
            [sys.executable, "-m", "pip", "install", *missings]
        )
        importlib.invalidate_caches()
    return

def checkResources(): # Check the resource type allocated to the Colab runtime:
    match torch.cuda.is_available():
        case True:
            print(f"{torch.cuda.device_count()} GPU(s) are available.\n")
        case False:
            print(f"No GPU: Using default resources -> {torch.__version__}\n")
    return

def loadScriptFile(): # Load & Execute the target file from GitHub:
    URL = "https://raw.githubusercontent.com/Landau184927/practice/main/test.py"
    # !wget -q -O test.py "$URL"
    # %run test.py
    return

def initializeTask(): # Initialize the Colab preparation process:
    PATH = "/content/drive"
    checkResources()
    testDependency()
    match os.path.exists(PATH):
        case True:
            return
        case False:
            drive.mount(PATH)
    return

def _initializer_():
    initializeTask()
    loadScriptFile()
    return

# Task Execution Layer:
_initializer_()
# Out:
# No GPU: Using default resources -> 2.11.0+cpu
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /content/test.py in <module>
#      45 if __name__ == "__main__":
#      46     URL = "https://raw.githubusercontent.com/chriswmann/datasets/master/500_Person_Gender_Height_Weight_Index.csv"
# ---> 47     task = Basic(URL)
#
# /content/test.py in __init__(self, URL)
#      15         init(autoreset = True, strip = False, convert = False)
#      16         self.data = pandas.read_csv(URL)
# ---> 17         self._initialize_()
#      18
#      19     def _initialize_(self):
#
# /content/test.py in _initialize_(self)
#      18
#      19     def _initialize_(self):
# ---> 20         self.setDataFrameStyle()
#      21
#      22     def convertLabelsForm(self): # Convert Numerical Labels to String Format:
#
# /content/test.py in setDataFrameStyle(self)
#      39     def setDataFrameStyle(self): # Set the Output Data Frame Style:
#      40         stylesheet = (self.convertLabelsForm().head(10).style.hide(axis = "index"))
# ---> 41         print(f"The following shows a sample {Fore.Green}(10 rows){Fore.RESET} of BMI data for 500 people.")
#      42         display(stylesheet)
#      43         # [!] Modify the Style
#
# AttributeError: 'AnsiFore' object has no attribute 'Green'

# %% [markdown]
# ### Task Execution Layer:

# %%
# Out:
# <pandas.io.formats.style.Styler object at 0x7a4747422990>
